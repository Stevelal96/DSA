# %%
# Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1. Reading the data in python
data= pd.read_csv('C:/Users/Stevelal/Downloads/week10.csv')
data
# Out:
#              ph    Hardness       Solids  Chloramines     Sulfate  \
# 0      8.316766  214.373394  22018.41744     8.059332  356.886136
# 1      9.092223  181.101509  17978.98634     6.546600  310.135738
# 2      5.584087  188.313324  28748.68774     7.544869  326.678363
# 3     10.223862  248.071735  28749.71654     7.513408  393.663395
# 4      8.635849  203.361523  13672.09176     4.563009  303.309771
# ...         ...         ...          ...          ...         ...
# 2006   8.989900  215.047358  15921.41202     6.297312  312.931021
# 2007   6.702547  207.321086  17246.92035     7.708117  304.510230
# 2008  11.491011   94.812545  37188.82602     9.263166  258.930600
# 2009   6.069616  186.659040  26138.78019     7.747547  345.700257
# 2010   4.668102  193.681736  47580.99160     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       363.266516       18.436525       100.341674   4.628771
# ...

# %%
# 2. Checking for null values
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %% [markdown]
# There is no null values present in the data

# %%
# 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

data[['Hardness','Sulfate', 'Organic_carbon']].describe()
# Out:
#           Hardness      Sulfate  Organic_carbon
# count  2011.000000  2011.000000     2011.000000
# mean    195.968072   333.224672       14.357709
# std      32.635085    41.205172        3.324959
# min      73.492234   129.000000        2.200000
# 25%     176.744938   307.632511       12.124105
# 50%     197.191839   332.232177       14.322019
# 75%     216.441070   359.330555       16.683049
# max     317.338124   481.030642       27.006707

# %%
x= data[['Hardness','Sulfate', 'Organic_carbon']]
x.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'Hardness'}>,
#         <AxesSubplot:title={'center':'Sulfate'}>],
#        [<AxesSubplot:title={'center':'Organic_carbon'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Inferences:
# 1. Variables Hardness, Sulfate and Organic carbon are normally distributed.
# 2. The mean values of the variables are as follows:
#    Hardness= 195.96, Sulfate= 333.22, Organic Carbon= 14.35
# 3. The standard deviation indicates that there are no abnormal divergence from the mean value

# %%
# 4. Carry out correlation analysis on the dataset and find the correlation factor between 
# a. ph and Chloramines 
# b. ph and Conductivity 
# What do we infer from this correlation value?
corrmatrix= data.corr()
plt.subplots(figsize=(10,6))
sns.heatmap(corrmatrix, vmin=-.5, vmax=.5, annot= True, linewidth= 0.2, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
cor_var= data[['ph','Chloramines','Conductivity']]
corrmatrix= cor_var.corr()
plt.subplots(figsize=(10,6))
sns.heatmap(corrmatrix, vmin=-.5, vmax=.5, annot= True, linewidth= 0.2, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# 1. There is no strong correlation between any of the variables.
# 2. Considering the ph and Chloramines the correlation value is -0.025, which is negative and too weak, thus we cannot establish any significant relation
# 3. Considering the ph and Conductivity the correlation value is 0.014, which is positive and too weak, thus we cannot establish any significant relation
